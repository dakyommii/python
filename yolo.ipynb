# %% [markdown]
# <a href="https://colab.research.google.com/github/dakyommii/study/blob/main/yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Mount Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls -al '/gdrive/My Drive/darknet'
# Out:
# total 12
# drwx------ 2 root root 4096 Oct  5 02:43 cfg
# drwx------ 2 root root 4096 Oct  5 02:43 data
# drwx------ 2 root root 4096 Oct  5 02:23 weights

# %%
weight_file = '/gdrive/My Drive/darknet/weights/yolov3.weights'
cfg_file = '/gdrive/My Drive/darknet/cfg/yolov3.cfg'
name_file = '/gdrive/My Drive/darknet/data/coco.names'

# %% [markdown]
# #2. Load File

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
min_confidence = 0.5

# %%
# Load Yolo
#weights와 cfg 파일 이용해 net 생성
net = cv2.dnn.readNet(weight_file, cfg_file)

# %%
classes = []
with open(name_file, 'r') as f:
    classes = [line.strip() for line in f.readlines()]

layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

colors = np.random.uniform(0, 255, size=(len(classes), 3))

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-50e5b49a-29f9-451a-87ad-b168b505c651" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50e5b49a-29f9-451a-87ad-b168b505c651">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car1.jpg to car1.jpg
# ...

# %%
img = cv2.imread('car1.jpg')
height, width, channels = img.shape
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F49179B7F10>

# %%
# Detecting objects
# https://docs.opencv.org/master/d6/d0f/group__dnn.html
blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)

net.setInput(blob)
outs = net.forward(output_layers)

# %%
class_ids = []
confidences = []
boxes = []

for out in outs:
    for detection in out:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]
        if confidence > min_confidence:
            # Object detected
            center_x = int(detection[0] * width)
            center_y = int(detection[1] * height)
            w = int(detection[2] * width)
            h = int(detection[3] * height)

            # Rectangle coordinates
            x = int(center_x - w / 2)
            y = int(center_y - h / 2)

            boxes.append([x, y, w, h])
            confidences.append(float(confidence))
            class_ids.append(class_id)

indexes = cv2.dnn.NMSBoxes(boxes, confidences, min_confidence, 0.4)
font = cv2.FONT_HERSHEY_COMPLEX
for i in range(len(boxes)):
    if i in indexes:
        x, y, w, h = boxes[i]
        label = str(classes[class_ids[i]])
        print(i, label)
        color = colors[i]
        cv2.rectangle(img, (x, y), (x + w, y + h), color, 2)
        cv2.putText(img, label, (x, y + 30), font, 0.5, (0, 255, 0), 1)  

cv2_imshow(img)
# Out:
# 0 car
# 1 truck
# 2 car
# 3 car
# 4 traffic light
# 5 car
# 6 truck
# 7 truck
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F4916152B90>
