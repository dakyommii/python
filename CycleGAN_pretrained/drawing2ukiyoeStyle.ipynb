# %% [markdown]
# <a href="https://colab.research.google.com/github/dakyommii/study/blob/main/CycleGAN_pretrained/drawing2ukiyoeStyle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix.git
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2428, done.
# remote: Total 2428 (delta 0), reused 0 (delta 0), pack-reused 2428
# Receiving objects: 100% (2428/2428), 8.13 MiB | 19.09 MiB/s, done.
# Resolving deltas: 100% (1561/1561), done.

# %%
# %cd pytorch-CycleGAN-and-pix2pix/
# !bash ./scripts/download_cyclegan_model.sh style_ukiyoe
# Out:
# [Errno 2] No such file or directory: 'pytorch-CycleGAN-and-pix2pix/'
# /content/pytorch-CycleGAN-and-pix2pix
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [style_ukiyoe]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-10-20 02:51:43--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/style_ukiyoe.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# ...

# %%
# !sudo pip install dominate

# %%
# !sudo pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 2.8 MB/s
# ...
#      |████████████████████████████████| 139 kB 55.5 MB/s
# ...
#      |████████████████████████████████| 97 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 180 kB 49.0 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.9 MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=3636679da0a556a4a15d23b032b4704e3c68c1b54b78098edd4dfd575b9f2393
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=f47ab0ad16e343f47cc749a9c9c48c100551bb2fa525c75884a5ee19cd22456a
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# ...

# %%
# !unzip -qq "/content/drive/MyDrive/data/drawing.zip"
# Out:
# replace drawing/simple2.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !python test.py --dataroot /content/pytorch-CycleGAN-and-pix2pix/drawing --name style_ukiyoe_pretrained --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /content/pytorch-CycleGAN-and-pix2pix/drawing	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: style_ukiyoe_pretrained       	[default: experiment_name]
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image

real = Image.open('/content/pytorch-CycleGAN-and-pix2pix/results/style_ukiyoe_pretrained/test_latest/images/simple1_real.png')
fake = Image.open('/content/pytorch-CycleGAN-and-pix2pix/results/style_ukiyoe_pretrained/test_latest/images/simple1_fake.png')

plt.imshow(real)
plt.show()
plt.imshow(fake)
plt.show()
