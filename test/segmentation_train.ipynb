# %% [markdown]
# <a href="https://colab.research.google.com/github/dakyommii/study/blob/main/test/segmentation_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #segmentation-train

# %% [markdown]
# ###train

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.models import Model
from keras.layers import Input, concatenate, Dropout, Reshape, Permute, Activation, ZeroPadding2D, Cropping2D, Add
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, DepthwiseConv2D
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
IMG_HEIGHT = 256
IMG_WIDTH = 256
BATCH_SIZE = 16

x_train = np.load('/content/drive/MyDrive/segmentation/data/x_train.npz')['data'].astype(np.float32)
y_train = np.load('/content/drive/MyDrive/segmentation/data/y_train.npz')['data'].astype(np.float32)
x_val = np.load('/content/drive/MyDrive/segmentation/data/x_val.npz')['data'].astype(np.float32)
y_val = np.load('/content/drive/MyDrive/segmentation/data/y_val.npz')['data'].astype(np.float32)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (4000, 256, 256, 3) (4000, 256, 256, 2)
# (80, 256, 256, 3) (80, 256, 256, 2)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    brightness_range=[0.7, 1.3]
)

val_datagen = ImageDataGenerator(
    rescale=1./255
)

train_gen = train_datagen.flow(
    x_train,
    y_train,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_gen = val_datagen.flow(
    x_val,
    y_val,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %%
inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# encode
conv1 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(inputs)
# conv1 = Dropout(0.2)(conv1)
conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv1)
pool1 = MaxPooling2D(pool_size=2)(conv1)
# (128, 128, 64)

shortcut_1 = pool1

conv2 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(pool1)
# conv2 = Dropout(0.2)(conv2)
conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv2)
pool2 = MaxPooling2D(pool_size=2)(conv2)
# (64, 64, 128)

shortcut_2 = pool2

conv3 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(pool2)
# conv3 = Dropout(0.2)(conv3)
conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv3)
pool3 = MaxPooling2D(pool_size=2)(conv3)
# (32, 32, 256)

# middle depthwiseconv nodes
shortcut_3 = pool3

mid = DepthwiseConv2D(3, activation='relu', padding='same', kernel_initializer='orthogonal')(pool3)
mid = Conv2D(256, 1, activation='relu', padding='same', kernel_initializer='orthogonal')(mid)

mid = DepthwiseConv2D(3, activation='relu', padding='same', kernel_initializer='orthogonal')(mid)
mid = Conv2D(256, 1, activation='relu', padding='same', kernel_initializer='orthogonal')(mid)

mid = Add()([shortcut_3, mid])

# decode
up8 = UpSampling2D(size=2)(mid)
up8 = concatenate([up8, conv3], axis=-1)
conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(up8)
# conv8 = Dropout(0.2)(conv8)
conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv8)
# (64, 64, 128)

conv8 = Add()([shortcut_2, conv8])

up9 = UpSampling2D(size=2)(conv8)
up9 = concatenate([up9, conv2], axis=-1)
conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(up9)
# conv9 = Dropout(0.2)(conv9)
conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv9)
# (128, 128, 64)

conv9 = Add()([shortcut_1, conv9])

up10 = UpSampling2D(size=2)(conv9)
up10 = concatenate([up10, conv1], axis=-1)
conv10 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(up10)
# conv10 = Dropout(0.2)(conv10)
conv10 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv10)
# (256, 256, 32)

conv11 = Conv2D(2, 1, padding='same', activation='relu',
                kernel_initializer='he_normal', kernel_regularizer=l2(0.005))(conv10)
conv11 = Reshape((IMG_HEIGHT * IMG_WIDTH, 2))(conv11)
# (256, 256, 2)

conv11 = Activation('softmax')(conv11)

outputs = Reshape((IMG_HEIGHT, IMG_WIDTH, 2))(conv11)

model = Model(inputs=inputs, outputs=outputs)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  18496       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  36928       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  73856       ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  147584      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  295168      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_5[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 32, 32, 256)  2560       ['max_pooling2d_2[0][0]']
#  v2D)
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  65792       ['depthwise_conv2d[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 32, 32, 256)  2560       ['conv2d_6[0][0]']
#  onv2D)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  65792       ['depthwise_conv2d_1[0][0]']
#
#  add (Add)                      (None, 32, 32, 256)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 256)  0           ['add[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 512)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 128)  589952      ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 128)  147584      ['conv2d_8[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 128)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 12  0          ['add_1[0][0]']
#                                 8)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 25  0           ['up_sampling2d_1[0][0]',
#                                 6)                                'conv2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 64  147520      ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_10[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 128, 128, 64  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_11[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 64  0          ['add_2[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 12  0           ['up_sampling2d_2[0][0]',
#                                 8)                                'conv2d_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 256, 256, 32  36896       ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 32  9248        ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 2)  66          ['conv2d_13[0][0]']
#
#  reshape (Reshape)              (None, 65536, 2)     0           ['conv2d_14[0][0]']
#
#  activation (Activation)        (None, 65536, 2)     0           ['reshape[0][0]']
#
#  reshape_1 (Reshape)            (None, 256, 256, 2)  0           ['activation[0][0]']
#
# ==================================================================================================
# Total params: 1,677,826
# Trainable params: 1,677,826
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(train_gen,
    validation_data=val_gen,
    epochs=100,
    callbacks=[
        ModelCheckpoint('/content/drive/MyDrive/segmentation/models/unet_no_drop.h5', monitor='val_acc', save_weights_only=True, verbose=1),
        ReduceLROnPlateau(monitor='val_acc', factor=0.2, patience=10, verbose=1, min_lr=1e-05)

    ]
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 250/250 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9937
# Epoch 1: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 110s 373ms/step - loss: 0.0505 - accuracy: 0.9937 - val_loss: 0.0071 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 2/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9976
# Epoch 2: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.0403 - accuracy: 0.9976 - val_loss: 0.0045 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 3/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9976
# Epoch 3: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 370ms/step - loss: 0.0392 - accuracy: 0.9976 - val_loss: 0.0041 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 4/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 4: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 5/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 5: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 6/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 6: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 7/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 7: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 8/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 8: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 9/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 9: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 10/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 10: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 11/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 11: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 12/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 12: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 13/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 13: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 14/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 14: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 15/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 15: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 16/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 16: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 17/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 17: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 18/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 18: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 19/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 19: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 20/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 20: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 21/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 21: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 22/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 22: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 23/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 23: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 24/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 24: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 25/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 25: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 26/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 26: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 27/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 27: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 28/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 28: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 29/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 29: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 30/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 30: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 31/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 31: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 32/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 32: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 33/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 33: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 34/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 34: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 35/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 35: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 36/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 36: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 37/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 37: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 38/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 38: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 39/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 39: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 40/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.9976
# Epoch 40: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1796 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 41/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 41: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 42/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 42: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 43/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 43: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 44/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 44: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 45/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 45: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 46/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 46: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 47/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 47: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 48/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 48: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 49/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 49: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 50/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 50: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 51/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 51: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 52/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 52: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 53/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 53: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 54/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9976
# Epoch 54: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1953 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 55/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 55: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 56/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 56: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 57/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 57: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 58/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 58: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 59/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 59: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 60/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 60: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 61/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 61: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 62/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 62: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 63/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 63: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 64/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 64: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 65/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 65: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 66/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 66: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 370ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 67/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 67: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 68/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 68: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 69/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 69: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 70/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9976
# Epoch 70: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 370ms/step - loss: 0.1952 - accuracy: 0.9976 - val_loss: 0.2562 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 71/100
# 250/250 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9976
# Epoch 71: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.1580 - accuracy: 0.9976 - val_loss: 0.0041 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 72/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 72: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0041 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 73/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 73: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0041 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 74/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 74: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0041 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 75/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 75: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 76/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 76: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 77/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 77: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 78/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 78: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 79/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 79: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 80/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 80: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 81/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 81: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 82/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 82: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 370ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 83/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 83: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 84/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 84: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 85/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 85: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 86/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 86: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 87/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 87: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 92s 369ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 88/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 88: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 88: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 89/100
# Epoch 89/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 89: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 89: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 90/100
# Epoch 90/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 90: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 90: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 91/100
# Epoch 91/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 91: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 91: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 92/100
# Epoch 92/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 92: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 92: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 93/100
# Epoch 93/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 93: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 93: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 94/100
# Epoch 94/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 94: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 94: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 95/100
# Epoch 95/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 95: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 95: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 371ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 96/100
# Epoch 96/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 96: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 96: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 97/100
# Epoch 97/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 97: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 97: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 98/100
# Epoch 98/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 98: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 98: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 373ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 373ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 99/100
# Epoch 99/100
# 250/250 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9976
# Epoch 99: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
#
# Epoch 99: saving model to /content/drive/MyDrive/segmentation/models/unet_no_drop.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# 250/250 [==============================] - 93s 372ms/step - loss: 0.0390 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9998 - lr: 0.0010
# Epoch 100/100
# Epoch 100/100
#  10/250 [>.............................] - ETA: 1:28 - loss: 0.0517 - accuracy: 0.9968

# %% [markdown]
# ###test

# %%
from keras.models import load_model
import matplotlib.pyplot as plt
import cv2
import numpy as np

import os

# %%
model = load_model('models/unet_no_drop.h5')

# %%
IMG_PATH = 'imgs/04.jpg'

img = cv2.imread(IMG_PATH, cv2.IMREAD_COLOR)
img_ori = cv2.cvtColor(img.copy(), cv2.COLOR_BGR2RGB)

plt.figure(figsize=(16, 16))
plt.imshow(img_ori)

# %%
IMG_WIDTH, IMG_HEIGHT = 256, 256

def preprocess(img):
    im = np.zeros((IMG_WIDTH, IMG_HEIGHT, 3), dtype=np.uint8)

    if img.shape[0] >= img.shape[1]:
        scale = img.shape[0] / IMG_HEIGHT
        new_width = int(img.shape[1] / scale)
        diff = (IMG_WIDTH - new_width) // 2
        img = cv2.resize(img, (new_width, IMG_HEIGHT))

        im[:, diff:diff + new_width, :] = img
    else:
        scale = img.shape[1] / IMG_WIDTH
        new_height = int(img.shape[0] / scale)
        diff = (IMG_HEIGHT - new_height) // 2
        img = cv2.resize(img, (IMG_WIDTH, new_height))

        im[diff:diff + new_height, :, :] = img
        
    return im

img = preprocess(img)

plt.figure(figsize=(8, 8))
plt.imshow(img)

# %%
input_img = img.reshape((1, IMG_WIDTH, IMG_HEIGHT, 3)).astype(np.float32) / 255.

pred = model.predict(input_img)

# %%
THRESHOLD = 0.5
EROSION = 1

def postprocess(img_ori, pred):
    h, w = img_ori.shape[:2]
    
    mask_ori = (pred.squeeze()[:, :, 1] > THRESHOLD).astype(np.uint8)
    max_size = max(h, w)
    result_mask = cv2.resize(mask_ori, dsize=(max_size, max_size))

    if h >= w:
        diff = (max_size - w) // 2
        if diff > 0:
            result_mask = result_mask[:, diff:-diff]
    else:
        diff = (max_size - h) // 2
        if diff > 0:
            result_mask = result_mask[diff:-diff, :]
        
    result_mask = cv2.resize(result_mask, dsize=(w, h))
    
    # fill holes
#     cv2.floodFill(result_mask, mask=np.zeros((h+2, w+2), np.uint8), seedPoint=(0, 0), newVal=255)
#     result_mask = cv2.bitwise_not(result_mask)
    result_mask *= 255

#     # erode image
#     element = cv2.getStructuringElement(cv2.MORPH_RECT, (2*EROSION + 1, 2*EROSION+1), (EROSION, EROSION))
#     result_mask = cv2.erode(result_mask, element)

    # smoothen edges
    result_mask = cv2.GaussianBlur(result_mask, ksize=(9, 9), sigmaX=5, sigmaY=5)
    
    return result_mask

mask = postprocess(img_ori, pred)

plt.figure(figsize=(16, 16))
plt.subplot(1, 2, 1)
plt.imshow(pred[0, :, :, 1])
plt.subplot(1, 2, 2)
plt.imshow(mask)

# %%
converted_mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

result_img = cv2.subtract(converted_mask, img_ori)
result_img = cv2.subtract(converted_mask, result_img)

plt.figure(figsize=(16, 16))
plt.imshow(result_img)

# %%
bg_img = cv2.imread('imgs/monalisa.jpg')
bg_img = cv2.cvtColor(bg_img, cv2.COLOR_BGR2RGB)

print(bg_img.shape, result_img.shape)

plt.figure(figsize=(16, 16))
plt.imshow(bg_img)
