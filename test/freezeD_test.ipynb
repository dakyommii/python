# %% [markdown]
# <a href="https://colab.research.google.com/github/dakyommii/study/blob/main/test/freezeD_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sangwoomo/FreezeD
# Out:
# Cloning into 'FreezeD'...
# remote: Enumerating objects: 156, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 156 (delta 23), reused 117 (delta 8), pack-reused 0
# Receiving objects: 100% (156/156), 43.85 MiB | 30.73 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !python '/content/FreezeD/stylegan/prepare_data.py' --dataset='tiger'  --n_worker 8
# Out:
# 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py:405: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py:405: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py:405: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# ...

# %%
# !python '/content/FreezeD/stylegan/precompute_acts.py' --dataset 'tiger'
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/inception.py:83: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   ' due to scipy/scipy#11299), please set init_weights=True.', FutureWarning)
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:01<00:00, 93.9MB/s]
# 100% 129/129 [00:01<00:00, 71.10it/s]

# %%
# !python '/content/FreezeD/stylegan/finetune.py' --dataset 'tiger' --ckpt '/content/drive/MyDrive/ckpt/sg2/stylegan_cat.model' --phase 2500 --eval_step 100 --save_step 500 --sample_num 250 --seed 50 --init_G --init_D  --only_adain --supervised  --miner 
# CUDA_VISIBLE_DEVICES=1 python finetune.py --name DATASET_freezeD --mixing --loss r1 --sched --dataset DATASET --freeze_D --feature_loc 3
# Note that feature_loc = 7 - layer_num
# Out:
# /content/FreezeD/stylegan/train.py:30: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   par1[k].data.mul_(decay).add_(1 - decay, par2[k].data)
# /usr/local/lib/python3.7/dist-packages/torchvision/models/inception.py:83: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   ' due to scipy/scipy#11299), please set init_weights=True.', FutureWarning)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:05<00:00, 109MB/s]
# ...
